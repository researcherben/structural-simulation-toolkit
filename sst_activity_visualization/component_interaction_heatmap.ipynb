# %% [markdown]
# TODO: need to know the component ID for each named sst.Component in the Python driver file

# %%
import json
import pandas

# %%
with open('config_network.json','r') as file_handle:
    network = json.load(file_handle)

# %%
network['links']
# Out:
# [{'name': 'link0',
#   'left': 'node_1',
#   'leftPort': 'port_a',
#   'right': 'node_0',
#   'rightPort': 'port_b',
#   'latency': '0ns'},
#  {'name': 'link1',
#   'left': 'node_2',
#   'leftPort': 'port_a',
#   'right': 'node_1',
#   'rightPort': 'port_b',
#   'latency': '0ns'},
#  {'name': 'link2',
#   'left': 'node_3',
#   'leftPort': 'port_a',
#   'right': 'node_2',
#   'rightPort': 'port_b',
#   'latency': '0ns'},
#  {'name': 'link3',
#   'left': 'node_4',
#   'leftPort': 'port_a',
#   'right': 'node_3',
#   'rightPort': 'port_b',
#   'latency': '0ns'},
#  {'name': 'link4',
#   'left': 'node_5',
#   'leftPort': 'port_a',
#   'right': 'node_4',
#   'rightPort': 'port_b',
#   'latency': '0ns'},
#  {'name': 'link5',
#   'left': 'node_6',
#   'leftPort': 'port_a',
#   'right': 'node_5',
#   'rightPort': 'port_b',
#   'latency': '0ns'},
#  {'name': 'link6',
#   'left': 'node_7',
#   'leftPort': 'port_a',
#   'right': 'node_6',
#   'rightPort': 'port_b',
#   'latency': '0ns'},
# ...

# %%
with open('simulation.dat','r') as file_handle:
    exchanges = file_handle.readlines()

# %%
df = pandas.DataFrame([eval(x) for x in exchanges])

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html

df_send = df[df['event type']=='send'].copy(deep=True)
df_send
# Out:
#     event type to port to component id on tick from port from component id
# 1         send     NaN             NaN       0    port_a                 0
# 3         send     NaN             NaN       0    port_a                 1
# 5         send     NaN             NaN       0    port_a                 2
# 7         send     NaN             NaN       0    port_a                 3
# 9         send     NaN             NaN       0    port_a                 4
# 11        send     NaN             NaN       0    port_a                 5
# 13        send     NaN             NaN       0    port_a                 6
# 15        send     NaN             NaN       0    port_a                 7
# 17        send     NaN             NaN       0    port_a                 8
# 19        send     NaN             NaN       1    port_a                 9
# 21        send     NaN             NaN       1    port_a                 0
# ...

# %%
def label_pair(row):
    for link_dict in network['links']:
        # TODO: the following is WRONG!
        if link_dict['right'][-1] == row['from component id']: 
            return link_dict['left'][-1]
        elif link_dict['left'][-1] == row['from component id']: 
            return link_dict['right'][-1]

# %%
df_send['to component id'] = df_send.apply(label_pair, axis=1)
df_send
# Out:
#     event type to port to component id on tick from port from component id
# 1         send     NaN               1       0    port_a                 0
# 3         send     NaN               0       0    port_a                 1
# 5         send     NaN               1       0    port_a                 2
# 7         send     NaN               2       0    port_a                 3
# 9         send     NaN               3       0    port_a                 4
# 11        send     NaN               4       0    port_a                 5
# 13        send     NaN               5       0    port_a                 6
# 15        send     NaN               6       0    port_a                 7
# 17        send     NaN               7       0    port_a                 8
# 19        send     NaN               8       1    port_a                 9
# 21        send     NaN               1       1    port_a                 0
# ...
